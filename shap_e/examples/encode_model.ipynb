# %%
import torch
import gc
import os
from shap_e.models.download import load_model
from shap_e.util.data_util import load_or_create_multimodal_batch
from shap_e.util.notebooks import create_pan_cameras, decode_latent_images, gif_widget

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
xm = load_model('transmitter', device=device)
torch.cuda.empty_cache()
torch.cuda.reset_peak_memory_stats()
torch.cuda.reset_accumulated_memory_stats()
gc.collect()
# !nvidia-smi
# Out:
# /home/grad/shap-e_GET3D/shap_e/models/nn/checkpoint.py:32: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(ctx, run_function, length, *args):
# /home/grad/shap-e_GET3D/shap_e/models/nn/checkpoint.py:44: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, *output_grads):
# /home/grad/shap-e_GET3D/shap_e/models/nn/checkpoint.py:62: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(ctx, run_function, length_1, length_2, *args):
# /home/grad/shap-e_GET3D/shap_e/models/nn/checkpoint.py:87: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, *all_output_grads):
# /home/grad/shap-e_GET3D/shap_e/models/download.py:136: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(path, map_location=device)
# Mon Jan 27 19:02:18 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.120                Driver Version: 550.120        CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2060        Off |   00000000:01:00.0 Off |                  N/A |
# | N/A   49C    P0             20W /   80W |    1807MiB /   6144MiB |     22%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      1542      G   /usr/lib/xorg/Xorg                              4MiB |
# |    0   N/A  N/A      5626      C   ...ad/anaconda3/envs/shap-e/bin/python       1798MiB |
# +-----------------------------------------------------------------------------------------+

# %%
model_path = "example_data/cactus/object.obj"

# This may take a few minutes, since it requires rendering the model twice
# in two different modes.
batch = load_or_create_multimodal_batch(
    device,
    model_path=model_path,
    mv_light_mode="basic",
    mv_image_size=256,
    cache_dir="example_data/cactus/cached",
    verbose=True, # this will show Blender output during renders
)
torch.cuda.empty_cache()
torch.cuda.reset_peak_memory_stats()
torch.cuda.reset_accumulated_memory_stats()
gc.collect()
# !nvidia-smi
# Out:
# Mon Jan 27 19:02:18 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.120                Driver Version: 550.120        CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2060        Off |   00000000:01:00.0 Off |                  N/A |
# | N/A   50C    P0             20W /   80W |    1809MiB /   6144MiB |     10%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      1542      G   /usr/lib/xorg/Xorg                              4MiB |
# |    0   N/A  N/A      5626      C   ...ad/anaconda3/envs/shap-e/bin/python       1800MiB |
# +-----------------------------------------------------------------------------------------+

# %%
with torch.no_grad():
    latent = xm.encoder.encode_to_bottleneck(batch)
    latent.shape
    
    render_mode = 'stf' # you can change this to 'nerf'
    size = 128 # recommended that you lower resolution when using nerf

    cameras = create_pan_cameras(size, device)
    images = decode_latent_images(xm, latent, cameras, rendering_mode=render_mode)
    display(gif_widget(images))
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[5], line 2
#       1 with torch.no_grad():
# ----> 2     latent = xm.encoder.encode_to_bottleneck(batch)
#       3     latent.shape
#       5     render_mode = 'stf' # you can change this to 'nerf'
#
# File ~/shap-e_GET3D/shap_e/models/transmitter/base.py:65, in VectorEncoder.encode_to_bottleneck(self, batch, options)
#      61 def encode_to_bottleneck(
#      62     self, batch: AttrDict, options: Optional[AttrDict] = None
#      63 ) -> torch.Tensor:
#      64     return self.latent_warp.warp(
# ---> 65         self.latent_bottleneck(self.encode_to_vector(batch, options=options), options=options),
#      66         options=options,
#      67     )
#
# File ~/shap-e_GET3D/shap_e/models/transmitter/base.py:114, in ChannelsEncoder.encode_to_vector(self, batch, options)
#     113 def encode_to_vector(self, batch: AttrDict, options: Optional[AttrDict] = None) -> torch.Tensor:
# --> 114     return self.encode_to_channels(batch, options=options).flatten(1)
#
# File ~/shap-e_GET3D/shap_e/models/transmitter/channels_encoder.py:193, in PerceiverChannelsEncoder.encode_to_channels(self, batch, options)
#     190 def encode_to_channels(
#     191     self, batch: AttrDict, options: Optional[AttrDict] = None
#     192 ) -> torch.Tensor:
# --> 193     h, it = self.get_h_and_iterator(batch, options=options)
#     194     n_unrolls = self.get_n_unrolls()
#     196     for _ in range(n_unrolls):
#
# File ~/shap-e_GET3D/shap_e/models/transmitter/channels_encoder.py:497, in PointCloudPerceiverChannelsEncoder.get_h_and_iterator(self, batch, options)
#     489 # Build the dataset embedding iterator
#     490 dataset_fn = {
#     491     "pcl": self.get_pcl_dataset,
#     492     "multiview": self.get_multiview_dataset,
#    (...)
#     495     "multiview_pcl": self.get_multiview_pcl_dataset,
#     496 }[self.cross_attention_dataset]
# --> 497 it = dataset_fn(batch, options=options)
#     499 return h, it
#
# File ~/shap-e_GET3D/shap_e/models/transmitter/channels_encoder.py:583, in PointCloudPerceiverChannelsEncoder.get_pcl_and_multiview_pcl_dataset(self, batch, options, use_distance)
#     578 _ = options
#     580 pcl_it = self.get_pcl_dataset(
#     581     batch, options=options, inner_batch_size=self.inner_batch_size[0]
#     582 )
# --> 583 multiview_pcl_emb = self.encode_multiview_pcl(batch, use_distance=use_distance)
#     584 batch_size, num_views, n_patches, width = multiview_pcl_emb.shape
#     586 assert num_views >= self.inner_batch_size[1]
#
# File ~/shap-e_GET3D/shap_e/models/transmitter/channels_encoder.py:713, in PointCloudPerceiverChannelsEncoder.encode_multiview_pcl(self, batch, use_distance)
#     711     depths = depths / ray_depth_factor
#     712 position = origin + depths * direction
# --> 713 all_view_poses = self.mv_pcl_embed(all_views, origin, position, mask)
#     715 batch_size, num_views, _, _, _ = all_view_poses.shape
#     717 views_proj = self.patch_emb(
#     718     all_view_poses.reshape([batch_size * num_views, *all_view_poses.shape[2:]])
#     719 )
#
# File ~/anaconda3/envs/shap-e/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/shap-e/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/shap-e_GET3D/shap_e/models/nn/encoding.py:171, in MultiviewPointCloudEmbedding.forward(self, channels, origin, position, mask)
#     169 x = torch.cat([channels, origin, position], dim=-3)
#     170 unk_token = torch.broadcast_to(self.unk_token.view(1, 1, -1, 1, 1), x.shape)
# --> 171 x = torch.where(mask, x, unk_token)
#     172 *batch_shape, in_features, height, width = x.shape
#     173 return (
#     174     super()
#     175     .forward(x.view(-1, in_features, height, width))
#     176     .view(*batch_shape, -1, height, width)
#     177 )
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 1.36 GiB. GPU 0 has a total capacity of 5.78 GiB of which 998.94 MiB is free. Including non-PyTorch memory, this process has 4.80 GiB memory in use. Of the allocated memory 4.60 GiB is allocated by PyTorch, and 93.55 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
