# %%
from IPython.display import display
import ipywidgets as widgets

# %%
x_input = widgets.Text(
    value="",
    placeholder="Enter value for x",
    description="x:",
    disabled=False
)

# %%
display(x_input)
# Out:
# Text(value='', description='x:', placeholder='Enter value for x')

# %%
def update_x(change):
    global x
    x = change['new']
    print(f"x has been updated to: {x}")

# %%
x_input.observe(update_x, names='value')

# %%
x = x_input.value

# %%
x
# Out:
# 'dsa'
